# %% [markdown]
# # Introduction to Python - Part1

# %%
# Sample Code - Intro 
print("Welcome to DataScience with Python ")
birth_year = input('what year were you born? ');
import datetime
x = datetime.datetime.now()
current_year = x.year
age = int(current_year) - int(birth_year)
print(f'you are {age} years old')

# %% [markdown]
# ## <u>Variables</u>
# - snake_case (conventional way),  case sensitive
# - unpacking is supported (also for lists, array, variables )
#
# ```python
#  a,b,c = 1,2,3
# ```
#
# - capital letters used to declare constants by convention
#
# ```python
#  constant $PI = 3.14 (
# ```
#
# ## <u>Data Types</u>
# - **INT FLOAT BOOL STR**
#   - Individual and basic
#   - Constructors : `int()`; `float()`; `bool()`; `str()`
#
#
# **REMINDER! :** expression (produces value) vs statement (entire code )
#
# ## <u>Operators</u>
#
# - ### <u>Arithmetic Operators</u>
#
#     - `+` Addition
#     - `-` Subtraction
#     - `*` Multiplication
#     - `/` Division
#     - `%` Mod (the remainder after dividing)
#     - `**` Exponentiation (note that `^` does not do this operation, which is a [Bitwise](https://wiki.python.org/moin/BitwiseOperators) operator)
#     - `//` Divides and rounds down to the nearest integer
#     - plus one `+=` ,  minus one `-=`
#
# - ### <u>Comparison Operators</u>
#
#     - `>` `<` `>=` `<=` `==` `!=`
#
# - ### <u>Logical Operators</u>
#     - `and` `or` `not`
#
# - ### <u>Identity  Operators</u>
#     - `is` evaluates if both sides have the same identity
#     - `is not` evaluates if both sides have different identities
#
# - ### <u>Membership</u>
#     - `in` `not in`
#
# **REMINDER! :** The difference between Comparison Operators and Identity Operators is checking <u>*equality vs. identity*</u>

# %%
# Sample Code - Strings 
name = 'burak'
surname = 'unuvar'
summary = ''' long string
 continues, continues 
 still goes on .... ''' 
fullname = name + ' ' + surname 
# print(fullname)
# print(summary)

# %% [markdown]
# ###   <u>String Methods</u>
#
#    - Strings are **immutable and ordered**
#      - can be indexed
#      - but a new value cannot be re-assigned
#    - `len` function, indexing and slicing are supported
#    - Built-in Functions or Methods
#    - Operators: Membership `in` `not in`
#    - Operators: Identity `is` `is not`
#
# ```python
#  sample='asdfghjkl'
#  sample[0] = 'b' # gives error, since a string is not mutable
#  len(sample)
# ```
#
#   - **Slice&Dice** to sort strings :
#
# ```python
#  sample[0:3] # starts with index zero, ends before index 3
#  sample[1:5:2] # start with index 1, stop before index 5, jump by 2
#  sample[1:]# start with - inclusive
#  sample[:5]# stop before - exclusive
#  sample[::1] # default behaviour
#  sample[::-1] # reverse string
#  sample[-2:] # starts with index -2, goes up, ends before index 0
#  sample[-2:0] # gives []
#  sample[-2:-4:-1] #starts with index -2, ends before index -4, jumps by 1
# ```
#
#   - Each of these methods accepts the string itself as the first argument of the method. However, they also could receive additional arguments, that are passed inside the parentheses
#
# ```python
#  full_name = 'burakunuvar'
#  len(full_name)
#  full_name.upper()
#  full_name.lower()
#  full_name.capitalize()
#  full_name.find('z')
#    # returns first occurrence of Substring
#  full_name.replace('burak', 'unuvar')
#    # Prints the string by replacing first with second
#  full.name.split()
#   #returns  a list that contains the words from the input string
#   # by default separator looks for whitespace to split, which can be updated with the first argument in method
#   # by default maxsplit covers all words in string.
# ```
#    - **Split** into list of strings
#
# ```python
#  new_str = "The cow jumped over the moon."
#  new_str.split() # default separator and max split
#  new_str.split(' ',3) # default separator and max split 3
#  new_str.split(None,2)  # default separator and max split 2
#
# ```
#
#    - **`IN` and `NOT IN`** membership operators
#
# ```python
#  'this' in 'this is a string' # True
#  'in' in 'this is a string' # True
#  'isa' in 'this is a string' #False
# ```
#
#   - **Copy**
#
# ```python
#  str_two = str_one
#  # copies value - they will take different locations in memory,therefore update on each doesn't affects another
#
# ```

# %%
# Sample Code - String Concatenation
username = input("enter your username: ")
password = input('enter your password: ')

password_length = len(password)
crypted_password = password_length * '*'
print("crypted_password: " + crypted_password)

print(f'Hi {username}, your password {crypted_password} is {password_length} letters long ')

print('hi again {}, once more your {} is {} letters long'.format(username,crypted_password,password_length ))

print('welcome {}, happy {}st birthday'.format('burak',34))

# %% [markdown]
# ## <u>Data Structures</u>
#   - **LIST TUPLE SET DICT**
#   - Data structures are containers that organize and group data types together in different ways.
#   - containers of data order data types into different structures
#   - Constructors : `list()`; `tuple()`; `set()`; `dict()`
#   - Built-in Functions or Methods
#    - Operators: Membership `in` `not in`
#    - Operators: Identity `is` `is not`
#
# **REMINDER** :  <u>*A data type*</u> is just a type that classifies data. This can include primitive (basic) data types like integers, booleans, and strings, as well as data structures, such as lists. <u>*Data structures*</u> are containers that organize and group data types together in different ways. For example, some of the elements that a list can contain are integers, strings, and even other lists!

# %% [markdown]
#
# ### 1. <u>Lists</u>
#
# - Lists are **mutable and ordered**
#   - can be indexed
#   - a new value can be re-assigned
# - ordered sequence of object, of any type
#
# ```python
#  list_one = [1,2,3,4,5]
#  list_two= ['a','b','c','d']
#   ```
#
# ###  <u> List Methods </u>
#   - **Add**
#
# ```python
#  list_one.append(6)
#  list_two.insert(2,'z')
#  list_one.extend([10,11,12])
# ```
#
#   - **Remove**
#
# ```python
#  list_one.pop()  # returns the removed item
#  list_two.remove('z')
#  list_one.clear()
# ```
#
#   - **Copy**
#
# ```python
#  copy_of_list = list_one[:] # new string created
#
#  str_two = str_one # copies value - they will take different locations in memory,therefore update on each does not affects another
#
#  list_two = list_one # copies pointer - they will both take same location in memory,therefore update on each affects another
#
#  new_copy = list_one[:]
#  new_copy2 = list_two.copy()
#
# ```
#    - **JOIN** as a larger string
#
# ```python
#  ''.join(['a','b','c']) # joins all with nothing in between all items
#  '\n'.join(['a','b','c']) # joins all with new line in between all items
#  '-'.join(['burak','unuvar','34']) #joins all with '-' in between all items
#   #reminder :  a string can't be joint with an int
# ```
#
#   - **Slice & Dice**
#
#     - Remember that the lower index is inclusive and the upper index is exclusive
#
# ```python
#  list_of_random_things = [1, 3.4, 'a string', True,"name","surname",["age",[]] ]
#  list_of_random_things[2:4]
# ```
#
#   - **`IN` & `NOT IN`** membership operators
#
# ```python
#  5 not in [1, 2, 3, 4, 6] # True
#  5 in [1, 2, 3, 4, 6] # False
# ```
#
#   - `LEN` `MIN` `MAX`
#
# ```python
#  len(my_list)
#  max(my_strings) # returns largest alphabetically
#  max(my_nums) # returns highest num
#  min(my_strings) # returns largest alphabetically
#  min(my_nums) # returns highest num
#  list_one.count(1) # counts the total number of an item )
#  list_two.index('d',0,2) # returns index of found
# ```
#
#    - `SORT` `SORTED` `REVERSE`
#
# ```PYTHON
#  list_one.sort() # updates list from smallest to largest ( or in alphabetical order )
#  new_list = sorted(list_two)
#  # produces a new array, returns a copy in order from smallest to largest
#  # original lost remains unchanged
#
#  list_two.reverse() # updates list in reverse order
#  list_two[::-1] #displays in reverse order - no update
# ```

# %%
# Sample Code - Lists 
# using this list, 
basket = ["Banana", "Apples", "Oranges", "Blueberries"];
# 1. Remove the Banana from the list
basket.remove("Banana")
# 2. Remove "Blueberries" from the list.
basket.pop()
# 3. Put "Kiwi" at the end of the list.
basket.append("Kiwi")
# 4. Add "Apples" at the beginning of the list
basket.insert(0,"Apples")
# 5. Count how many apples in the basket
basket.count("Apples")
# 6. empty the basket
basket.clear()
print(basket)

#fix this code so that it prints a sorted list of all of our friends (alphabetical). Scroll to see answer
friends = ['Simon', 'Patty', 'Joy', 'Carrie', 'Amira', 'Chu']

new_friend = ['Stanley']

friends.append(new_friend[0])
friends.sort()

# print(friends.sort() + new_friend)

friends.reverse()
print(friends)
print(sorted(friends))

# friends.extend(new_friend)
# print(sorted(friends))

# %% [markdown]
# ### 2. <u>Tuples </u>
#
# - Tuples are *immutable and ordered**
#   - can be indexed
#   - a new value can not be re-assigned
# - immutable ordered sequences of elements.
# - Often used to store related pieces of information - like latitude & longitude:
#
# ```python
#  my_tuple = (1,2,3,4,5)
#  #cannot be sorted, reversed,changed
#  #can be used for dictionaries
# ```
#
# - Unpacking is supported to assign the information from a tuple into multiple variables without having to access them one by one and make multiple assignment statements
#
# ```python
#  a,b,c = (1,2,3)
#  a,b,c,*other,d = (1,2,3,4,5,6,7,8)
#
#  length, width, height = 52, 40, 100 #parantheses are optional
#  print("The dimensions are {} x {} x {}".format(length, width, height))
# ```
#
# ### <u> Tuple Methods </u>
#
# - slicing and many other array methods are supported
#
# ```python
#  new_tuple = my_tuple[1:2]
#  x,y,*other,z = my_tuple
#  my_tuple.count(1)
#  my_tuple.index(1)
# ```

# %% [markdown]
# ### 3.  <u>Sets </u>
#
# - mutable unordered collections of unique elements
# - an example of use-case is usernames, emails etc
#
# ```python
#  my_set = {1,2,3,4,5}
#
#  my_set.add(2)
#  # does nothing since 2 already exists
#  my_list = [1,2,3,4,5,5]
#  my_set = {1,2,3,4,5,5}
#  # removes duplicates , which is 5 in this case
#  set(my_list)
#  list(my_set)
# ```
#
#
# ### <u> Set Methods </u>
#
# - `ADD` `POP` `DISCARD`
#
# ```python
#  my_set.add(100)# is instead of append
#  my_set.pop() # works but removes a random element , since there is no order
#  set_one.discard(2)
# ```
#
# - `IN` `LEN` `COUNT` work as they do in LISTs
#
# ```python
#  5 in my_set
#  len(my_set)
#  # counts only unique values
#  copy_set = my_set.copy() # complete new copy
# ```
#
# -  `union`, `intersection`, and `difference`
# - Those methods easy to perform with sets, and are much faster than such operators with other containers.
#
# ```python
#  set_one = {1,2,3,4,5}
#  set_two = {4,5,6,7,8,9}
#  set_one.difference(set_two)
#
#  set_one.difference_update(set_two)
#  # keeps only the different attributes
#
#  set_one.intersection(set_two)
#  set_one.isdisjoint(set_two)
#  # returns TRUE or False  set_one.issubset(set_two)
#
#  set_two.issuperset(set_one)
#  set_one.union(set_two)
#  # merges two sets, removes duplicates
#
#  set_one | set_two
#  # another declaration to merge without duplicates
#
#  ```

# %% [markdown]
# ### 4.  <u>Dictionaries </u>
# - a mutable data type that stores mappings of unique keys to values ( unordered "key:value" pairs )
# - Dictionaries can have keys of any immutable type, like integers or tuples, not just strings.
# - keys need to have special property that is immutable (number, boolean, string );so a list can't be a key
#
# **Hint! : `TypeError: unhashable type: 'list'`**
#
#   => In Python, any immutable object (such as an integer, boolean, string, tuple) is hashable, meaning its value does not change during its lifetime. This allows Python to create a unique hash value to identify it, which can be used by dictionaries to track unique keys and sets to track unique values. This is why Python requires us to use immutable datatypes for the keys in a dictionary.
#
# ```python
#  user = {
#   'name' : 'burak',
#   'age' : 34,
#   'married' : False,
#   'skills' : ['cloud']
#     }
#  user['surname'] = 'unuvar'
#  print('name' in user)
#
#  print(user['surname'])
#  # returns the value for the given key - if present in the dictionary.
#  # If not present, it will give ERROR
#
#  print(user.get('age'))
#  # returns the value for the given key - if present in the dictionary.
#  # If not present, it will return None
#
# ```
#
# ### <u> Dictionary methods </u>
#
# - `GET` `UPDATE`
#
# ```python
#  user.get('alias') # false
#  user['alias'] = "buraku"
#  user.update({"nation":'TR'})
#  user.get('age') # true
#  user.get('age', false )
#  #get looks up values in a dictionary, but unlike square brackets, get returns None (or a default value of your choice) if the key isn't found (or a default value of your choice) .
#  user.get('birthday', 'There\'s no such element!') # "There's no such element!"
# ```
# - `IN` `NOT IN` `LEN`
#
# ```python
#  len(user)
#  'name' in user # TRUE
#  'country' in user # FALSE
#  'attribute' in user.keys()
#  'attribute' in user.values()
#  'attribute' in user.items()  # returns tuple
# ```
#
# ```python
#  user.copy()
#  user.pop('age')
#  user.popitem() # random choice for removal
#  user.clear()
# ```
#
# **HINT! <u>Creating a dictionary is by a constructor </u>**
#
# ```python
# user2 = dict (name='pinar' , surname='isik' , age=38  )
# ```
#   => A set is defined as a sequence of elements separated by commas:
#
#    `set_example = {element1, element2, element3}`
#
#   => While a dictionary is defined as a sequence of key, value pairs marked with colons, separated by commas:
#
#    `dict_example = {key1: value1, key2: value2, key3: value3}`
#
#   => if you define a variable with an empty set of curly braces like this: `a = {}`, Python will assign an empty dictionary to that variable. You can always use `set()` and `dict()` to define empty sets and dictionaries as well.

# %%
# Sample Code - Dictionaries
#1 Create a user profile for your new game. This user profile will be stored in a dictionary with keys: 'age', 'username', 'weapons', 'is_active' and 'clan'

my_profile = { 
  'age' : 34 ,
  'username' : 'buraku',
  'infected' : None,
  'is_active' : True,
  'doctor' : 'unknown'
  }

#2 iterate and print all the keys in the above user.

print( my_profile.keys() )
print( my_profile.items() )
print( my_profile.values() )

#3 Add a new key to include 'is_banned'. Set it to false
my_profile['is_banned'] = False
print (my_profile['is_banned'] )


#6 create a new user2 my copying the previous user and update the age value and username value. 
new_user= my_profile.copy()
new_user['username'] = 'pinar'
print(new_user)

# %%
# Sample Code - Sets 

# You are working for the school Principal. We have a database of school students:
school = {'Bobby','Tammy','Jammy','Sally','Danny'}

#during class, the teachers take attendance and compile it into a list. 
attendance_list = ['Jammy', 'Bobby', 'Danny', 'Sally']

#using what you learned about sets, create a piece of code that the school principal can use to immediately find out who missed class so they can call the parents. (Imagine if the list had 1000s of students. The principal can use the lists generated by the teachers + the school database to use python and make his/her job easier): Find the students that miss class!

print(school.difference(attendance_list))

attendees = set(attendance_list)
print(school.difference(attendees))
#print(attendees)

#Solution: Notice how we don't have to convert the attendance_list to a set...it does it for you.
#print(school.difference(attendance_list))

# %% [markdown]
# ###  <u>Extra Bits of Info </u>
#
# - #### Math Functions ( built-in )
#
# ```python
#  round(1.5)
#  abs(-20)
#  bin(5)
#  int ('0b101',2)
# ```
#
# - #### Range
#   - mostly used for iterations
#
# ```python
# range(100) # generates 100 nums , starting with 0
# range(1,100) # starts with 1, 100 not included
#
# ```
#
#
# - #### Unpacking
#
# ```python
#  a,b,c = [1,2,3]
#  a,b,c,*other,d = [1,2,3,4,5,6,7,8]
# ```
#
# - ####  Compound Data Structures
#
# ```python
# elements = {"hydrogen": {"number": 1,
#                          "weight": 1.00794,
#                          "symbol": "H"},
#               "helium": {"number": 2,
#                          "weight": 4.002602,
#                          "symbol": "He"}}
# ```

# %% [markdown]
#
# | Data Structure | Ordered | Mutable  | Constructor  | An example           |
# | -------------- | ------- |--------- |------------- |  -----------         |
# | List           | Yes     |Yes       |[ ] or list() |[5.7, 4, 'yes', 5.7]  |
# | Tuple          | Yes     |No        |( ) or tuple()|(5.7, 4, 'yes', 5.7)  |
# | Set            | No      |Yes       |{}* or set()  |{5.7, 4, 'yes'}       |
# | Dictionary     | No      |Yes-No**  |{ } or dict() |{'Jun': 75, 'Jul': 89}|
#
# - If you leave the curly braces empty like this: {} Python will instead create an empty dictionary
# - A dictionary itself is mutable, but each of its individual keys must be immutable
